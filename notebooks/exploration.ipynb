# %% [markdown]
# # Bayesian Deep Learning Exploration
#
# This notebook demonstrates the key concepts of Bayesian Deep Learning using our implementation.
#
# ## Key Concepts
# - **Bayesian Neural Networks**: Weights as distributions
# - **Uncertainty Quantification**: Measuring prediction confidence
# - **Variational Inference**: Approximating posterior distributions
# - **Monte Carlo Dropout**: Efficient uncertainty estimation
